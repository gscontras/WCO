# %% [markdown]
# Package for accessing and manupulating data frames:

# %%
import pandas as pd
CSV_FILE_LOCATION = "http://localhost:8888/edit/experiments/1-rating/stimuli-gen/WCO%20stimuli%20break%20down.csv"
TXT_OR_JSON_FILE_SAVE_LOCATION = "http://localhost:8888/edit/experiments/1-rating/stimuli-gen/"
iDontKnowIfIAmSupposedToIncludeThisLineOfCode = False

# %%
df = pd.read_csv(CSV_FILE_LOCATION)

# %%
def program():    
    dataList = list()
    
    i = 0
    for l in df['Label']:
        dataList.append([l, "", "", ""])
        i += 1
    
    i = 0
    for cond in df['Condition']:
        dataList[i][1] = cond
        i += 1
        
    i = 0
    for s in df['Sentence example']:
        dataList[i][2] = s
        i += 1
        
    i = 0
    for cont in df['Context']:
        dataList[i][3] = cont
        i += 1
        
    for item in dataList:
        #item: [Label, Condition, Sentence, Context]
        label = item[0]
        condition = item[1]
        sentence = item[2]
        context = item[3]

    def functionOne(label: str, condition: str, sentence: str, context: str) -> str:
        returnStr = str()
        if iDontKnowIfIAmSupposedToIncludeThisLineOfCode:
            returnStr += "codeString"
            returnStr += condition
            returnStr += " = "

        returnStr += condition
        returnStr += ": {story: \""
        returnStr += context
        returnStr += "\", "

        returnStr += "sentence: \""
        returnStr += sentence
        returnStr += "\", "

        returnStr += "label: \""
        returnStr += label
        returnStr += "\"}"

        return returnStr

    def functionTwo(itemtype: str, label: str, dL: list) -> str:
        returnstr = label + "xconfig = \n"
        returnstr += "{itemtype: \""
        returnstr += itemtype
        returnstr += "\",\n\n"
        for item in dL:
            #item: [Label, Condition, Sentence, Context]
            if label == item[0]:
                returnstr += functionOne(item[0], item[1], item[2], item[3])
                returnstr += ",\n\n"
            
        #we don't want the extra comma/newlines at the end hence [:-3]
        returnstr = returnstr[:-3] + "\n}"
        
        fileLocation = TXT_OR_JSON_FILE_SAVE_LOCATION + label + "-expconfig.js"
        print (fileLocation)
        codeFile = open(fileLocation, 'w')
        codeFile.write(returnstr)
        codeFile.close()
        return "done! Yay!" + returnstr
    
    i = 0
    while i < len(dataList):
        print(functionTwo(itemtype= 'test', label= dataList[i][0], dL= dataList))
        i += 8
        
    print(functionTwo(itemtype= 'test', label= 'queen', dL= dataList))

#if __name__ == '__main__':
program()
# Out:
# /Users/vinny/Downloads/pilot-expconfig.txt
# done! Yay!pilotxconfig =
# {itemtype: "test",
#
# YQA: {story: "Flight attendants are paired with certain pilots. Some flight attendants were flown around the country by their pilots, and others were not.", sentence: "Every flight attendant who her pilot flew around the country avoided turbulence", label: "pilot"},
#
# YQI: {story: "Planes are paired with certain pilots. Some planes were flown around the country by their pilots, and others were not.", sentence: "Every plane which its pilot flew around the country avoided turbulence", label: "pilot"},
#
# YDA: {story: "Flight attendants are paired with certain pilots.  A flight attendant was flown around the country by her pilot and another was not.", sentence: "The flight attendant who her pilot flew around the country avoided turbulence", label: "pilot"},
#
# YDI: {story: "Planes are paired with certain pilots. A plane was flown around the country by its pilot, and another was not.", sentence: "The plane which its pilot flew around the country avoided turbulence", label: "pilot"},
#
# NQA: {story: "There is a certain pilot. Some flight attendants were flown around the country by that pilot, and others were not.", sentence: "Every flight attendant who the pilot flew around the country avoided turbulence", label: "pilot"},
#
# NQI: {story: "There is a certain pilot. Some planes were flown around the country by that pilots, and others were not.", sentence: "Every plane which the pilot flew around the country avoided turbulence", label: "pilot"},
#
# NDA: {story: "There is a certain pilot. A flight attendant was flown around the country by that pilot and another was not.", sentence: "The flight attendant who the pilot flew around the country avoided turbulence", label: "pilot"},
#
# NDI: {story: "There is a certain pilot. A plane was flown around the country by that pilot, and another was not.", sentence: "The plane which the pilot flew around the country avoided turbulence", label: "pilot"}
# }
# /Users/vinny/Downloads/pianist-expconfig.txt
# done! Yay!pianistxconfig =
# {itemtype: "test",
#
# YQA: {story: "Singers are paired with certain pianists. Some singers were heard by their pianist during rehearsal, and others were not. ", sentence: "Every singer who her pianist heard during rehearsal sounded beautiful", label: "pianist"},
#
# YQI: {story: "Pianos are paired with certain pianists. Some pianos were heard by their pianist during rehearsal, and others were not. ", sentence: "Every piano which its pianist heard during rehearsal sounded beautiful", label: "pianist"},
#
# YDA: {story: "Singers are paired with certain pianists. A singer was heard by their pianist during rehearsal, and another was not. ", sentence: "The singer who her pianist heard during rehearsal sounded beautiful", label: "pianist"},
#
# YDI: {story: "Pianos are paired with certain pianists. A piano was heard by their pianist during rehearsal, and another was not. ", sentence: "The piano which its pianist heard during rehearsal sounded beautiful", label: "pianist"},
#
# NQA: {story: "There is a certain pianist. Some singers were heard by that pianist during rehearsal, and others were not. ", sentence: "Every singer who the pianist heard during rehearsal sounded beautiful", label: "pianist"},
#
# NQI: {story: "There is a certain pianist. Some pianos were heard by that pianist during rehearsal, and others were not. ", sentence: "Every piano which the pianist heard during rehearsal sounded beautiful", label: "pianist"},
#
# NDA: {story: "There is a certain pianist. A singer was heard by that pianist during rehearsal, and another was not. ", sentence: "The singer who the pianist heard during rehearsal sounded beautiful", label: "pianist"},
#
# NDI: {story: "There is a certain pianist. A piano was heard by that pianist during rehearsal, and another was not. ", sentence: "The piano which the pianist heard during rehearsal sounded beautiful", label: "pianist"}
# }
# /Users/vinny/Downloads/queen-expconfig.txt
# done! Yay!queenxconfig =
# {itemtype: "test",
#
# YQA: {story: "Princesses are paired with certain queens. Some princesses are admired by their queens, and others are not.", sentence: "Every princess who her queen admired was featured in the royal portrait", label: "queen"},
#
# YQI: {story: "Princesses are paired with certain queens. Some tiaras are admired by their queens, and others are not.", sentence: "Every tiara which its queen admired was featured in the royal portrait", label: "queen"},
#
# YDA: {story: "Princesses are paired with certain queens. A princess was admired by her queen and another was not.", sentence: "The princess who her queen admired was featured in the royal portrait", label: "queen"},
#
# YDI: {story: "Princesses are paired with certain queens. A tiara was admired by its queen, and another was not.", sentence: "The tiara which its queen admired was featured in the royal portrait", label: "queen"},
#
# NQA: {story: "There is a certain queen. Some princesses are admired by that queen, and others are not.", sentence: "Every princess who the queen admired was featured in the royal portrait", label: "queen"},
#
# NQI: {story: "There is a certain queen. Some tiaras are admired by that queens, and others are not.", sentence: "Every tiara which the queen admired was featured in the royal portrait", label: "queen"},
#
# NDA: {story: "There is a certain queen. A princess was admired by that queen and another was not.", sentence: "The princess who the queen admired was featured in the royal portrait", label: "queen"},
#
# NDI: {story: "There is a certain queen. A tiara was admired by that queen, and another was not.", sentence: "The tiara which the queen admired was in the royal portrait", label: "queen"}
# }
# /Users/vinny/Downloads/conductor-expconfig.txt
# done! Yay!conductorxconfig =
# {itemtype: "test",
#
# YQA: {story: "Floutists are paired with certain conductors. Some floutists were seen by their conductor on stage, and others were not. ", sentence: "Every floutist who her conductor saw on the stage needed to be in the orchestra pit", label: "conductor"},
#
# YQI: {story: "Trumpets are paired with certain conductors. Some trumpets were seen by their conductor on stage, and others were not. ", sentence: "Every trumpet which its conductor saw on the stage needed to be in the orchestra pit", label: "conductor"},
#
# YDA: {story: "Floutists are paired with certain conductors. A floutist was seen by their conductor on stage, and others were not. ", sentence: "The floutist who her conductor saw on the stage needed to be in the orchestra pit", label: "conductor"},
#
# YDI: {story: "Trumpets are paired with certain conductors. A trumpet was seen by their conductor on stage, and others were not. ", sentence: "The trumpet which its conductor saw on the stage needed to be in the orchestra pit", label: "conductor"},
#
# NQA: {story: "There is a certain conductor. Some floutists were seen by that conductor on stage, and others were not. ", sentence: "Every floutist who the conductor saw on the stage needed to be in the orchestra pit", label: "conductor"},
#
# NQI: {story: "There is a certain conductor. Some trumpets were seen by that conductor on stage, and others were not. ", sentence: "Every trumpet which the conductor saw on the stage needed to be in the orchestra pit", label: "conductor"},
#
# NDA: {story: "There is a certain conductor. A floutist was seen by that conductor on stage, and another was not. ", sentence: "The floutist who the conductor saw on the stage needed to be in the orchestra pit", label: "conductor"},
#
# NDI: {story: "There is a certain conductor. A trumpet was seen by that conductor on stage, and another was not. ", sentence: "The trumpet which the conductor saw on the stage needed to be in the orchestra pit", label: "conductor"}
# }
# /Users/vinny/Downloads/artist-expconfig.txt
# done! Yay!artistxconfig =
# {itemtype: "test",
#
# YQA: {story: "Models are used by painters. Some models were painted on canvas by their artists, and other models were not.", sentence: "Every model who her artist painted on canvas looked stunning", label: "artist"},
#
# YQI: {story: "Portraits are painted by painters. Some portraits were painted on canvas by their artists, and other portraits were not.", sentence: "Every portrait which its artist painted on canvas looked stunning", label: "artist"},
#
# YDA: {story: "Models are used by painters. A model was painted on canvas by her artist and another model was not.", sentence: "The model who her artist painted on canvas looked stunning", label: "artist"},
#
# YDI: {story: "Portraits are painted by painters. A portrait was painted on canvas by its artist, and another portrait was not.", sentence: "The portrait which its artist painted on canvas looked stunning", label: "artist"},
#
# NQA: {story: "There is a certain artist. Some models were painted on canvas by that artist, and other models were not.", sentence: "Every model who the artist painted on canvas looked stunning", label: "artist"},
#
# NQI: {story: "There is a certain artist. Some portraits were painted on canvas by that artists and other portraits were not.", sentence: "Every portrait which the artist painted on canvas looked stunning", label: "artist"},
#
# NDA: {story: "There is a certain artist. A model was painted on canvas by that artist and another model was not.", sentence: "The model who the artist painted on canvas looked stunning", label: "artist"},
#
# NDI: {story: "There is a certain artist. A portrait was painted on canvas by that artist, and another portrait was not.", sentence: "The portrait which the artist painted on canvas looked stunning", label: "artist"}
# }
# /Users/vinny/Downloads/supervisor-expconfig.txt
# done! Yay!supervisorxconfig =
# {itemtype: "test",
#
# YQA: {story: "Police women are assigned certain supervisors. Some police women were observed by their respective supervisor at the precint, and others were not. ", sentence: "Every policewoman who her supervisor observed at the precinct was up to the the task", label: "supervisor"},
#
# YQI: {story: "Computers are assigned certain supervisors. Some computers were observed by its respective supervisor at the precint, and others were not. ", sentence: "Every computer which its supervisor observed at the precinct was up to the the task", label: "supervisor"},
#
# YDA: {story: "Police women are assigned certain supervisors. A police woman was observed by their supervisor at the precint, and others were not.", sentence: "The policewoman who her supervisor observed at the precinct was up to the the task", label: "supervisor"},
#
# YDI: {story: "Computers are assigned certain supervisors. A computer was observed at the precint by its supervisor, and others were not. ", sentence: "The computer which its supervisor observed at the precinct was up to the the task", label: "supervisor"},
#
# NQA: {story: "There is a certain supervisor. Some police women were observed by this supervisor at the precint, and others were not. ", sentence: "Every policewoman who the supervisor observed at the precinct was up to the the task", label: "supervisor"},
#
# NQI: {story: "There is a certain supervisor. Some computers were observed by this supervisor at the precint, and others were not. ", sentence: "Every computer which the supervisor observed at the precinct was up to the the task", label: "supervisor"},
#
# NDA: {story: "There is a certain supervisor. A police woman was observed by this supervisor at the precint, and others were not. ", sentence: "The policewoman who the supervisor observed at the precinct was up to the the task", label: "supervisor"},
#
# NDI: {story: "There is a certain supervisor. A computer was observed by this supervisor at the precint, and others were not. ", sentence: "The computer which the supervisor observed at the precinct was up to the the task", label: "supervisor"}
# }
# /Users/vinny/Downloads/doctor-expconfig.txt
# done! Yay!doctorxconfig =
# {itemtype: "test",
#
# YQA: {story: "Nurses work for certain doctors. Some nurses were consulted with their doctor, and others were not.", sentence: "Every nurse who her doctor consulted at the clinic offered valuable insight", label: "doctor"},
#
# YQI: {story: "Labs are supervised by certain doctors. Some labs were consulted with their doctor, and others were not.", sentence: "Every lab which its doctor consulted at the clinic offered valuable insight", label: "doctor"},
#
# YDA: {story: "Nurses work for certain doctors. A nurse was consulted with their doctor, and others were not.", sentence: "The nurse who her doctor consulted at the clinic offered valuable insight", label: "doctor"},
#
# YDI: {story: "Labs are supervised by certain doctors. A lab was consulted by its doctor, and others were not.", sentence: "The lab which its doctor consulted at the clinic offered valuable insight", label: "doctor"},
#
# NQA: {story: "There is a certain doctor. Some nurses were consulted with the doctor, and others were not.", sentence: "Every nurse who the doctor consulted at the clinic offered valuable insight", label: "doctor"},
#
# NQI: {story: "There is a certain doctor. Some labs were consulted with the doctor, and others were not.", sentence: "Every lab which the doctor consulted at the clinic offered valuable insight", label: "doctor"},
#
# NDA: {story: "There is a certain doctor. A nurse was consulted with the doctor, and others were not.", sentence: "The nurse who the doctor consulted at the clinic offered valuable insight", label: "doctor"},
#
# NDI: {story: "There is a certain doctor. A lab was consulted by its doctor, and others were not.", sentence: "The lab which the doctor consulted at the clinic offered valuable insight", label: "doctor"}
# }
# /Users/vinny/Downloads/travel agent-expconfig.txt
# done! Yay!travel agentxconfig =
# {itemtype: "test",
#
# YQA: {story: "Tour guides are endorsed by certain travel agents. Some tour guides were endorsed by their travel agent, others were not. ", sentence: "Every tour guide who her travel agent endorsed in a tweet sold out of tickets", label: "travel agent"},
#
# YQI: {story: "Guided tours are endorsed by certain travel agents.  Some guided tours were endorsed by their travel agent, others were not. ", sentence: "Every guided tour which its travel agent endorsed in a tweet sold out of tickets", label: "travel agent"},
#
# YDA: {story: "Tour guides are endorsed by certain travel agents. A tour guide was endorsed by her travel agent, another was not. ", sentence: "The tour guide who her travel agent endorsed in a tweet sold out of tickets", label: "travel agent"},
#
# YDI: {story: "Guided tours are endorsed by certain travel agents.  A guided tour was endorsed by its travel agent, another was not. ", sentence: "The guided tour which its travel agent endorsed in a tweet sold out of tickets", label: "travel agent"},
#
# NQA: {story: "There is a certain travel agent. Some tour guides were endorsed by the travel agent, others were not. ", sentence: "Every tour guide who the travel agent endorsed in a tweet sold out of tickets", label: "travel agent"},
#
# NQI: {story: "There is a certain travel agent. Some guided tours were endorsed by the travel agent, others were not. ", sentence: "Every guided tour which the travel agent endorsed in a tweet sold out of tickets", label: "travel agent"},
#
# NDA: {story: "There is a certain travel agent. A tour guide was endorsed by the travel agent, another was not. ", sentence: "The tour guide who the travel agent endorsed in a tweet sold out of tickets", label: "travel agent"},
#
# NDI: {story: "There is a certain travel agent. A guided tour was endorsed by the travel agent, another was not. ", sentence: "The guided tour which the travel agent endorsed in a tweet sold out of tickets", label: "travel agent"}
# }
# /Users/vinny/Downloads/playwright-expconfig.txt
# done! Yay!playwrightxconfig =
# {itemtype: "test",
#
# YQA: {story: "Directors are overseen by certain playwrights. Some directors were addressed by their playwright, and others were not.", sentence: "Every director who her playwright addressed in the meeting needed considerable help", label: "playwright"},
#
# YQI: {story: "Scripts are written certain playwrights. Some scripts were addressed by their playwright, and others did not.", sentence: "Every script which its playwright addressed in the meeting needed considerable help", label: "playwright"},
#
# YDA: {story: "Directors are overseen by certain playwrights. A director was adressed by her playwright, and others were not.", sentence: "The director who her playwright addressed in the meeting needed considerable help", label: "playwright"},
#
# YDI: {story: "Scripts are written by certain playwrights. A script was addressed by its playwright, and others were not.", sentence: "The script which its playwright addressed in the meeting needed considerable help", label: "playwright"},
#
# NQA: {story: "There is a certain playwright. Some directors were addressed by the playwright, and others were not.", sentence: "Every director who the playwright addressed in the meeting needed considerable help", label: "playwright"},
#
# NQI: {story: "There is a certain playwright. Some scripts were adressed by the playwright, and others were not.", sentence: "Every script which the playwright addressed in the meeting needed considerable help", label: "playwright"},
#
# NDA: {story: "There is a certain playwright. A director was adressed by her playwright, and others were not.", sentence: "The director who the playwright addressed in the meeting needed considerable help", label: "playwright"},
#
# NDI: {story: "There is a certain playwright. A script was adressed by its playwright, and others were not.", sentence: "The script which the playwright addressed in the meeting needed considerable help", label: "playwright"}
# }
# /Users/vinny/Downloads/professor-expconfig.txt
# done! Yay!professorxconfig =
# {itemtype: "test",
#
# YQA: {story: "Students have certain professors. Some students were presented to the faculty by their professor, and others were not.", sentence: "Every student who her professor presented to the faculty influenced the dean.", label: "professor"},
#
# YQI: {story: "Manuscripts are written by certain professors. Some manuscripts were presented to the faculty by its professor, and others were not.", sentence: "Every manuscript which its professor presented to the faculty influenced the dean.", label: "professor"},
#
# YDA: {story: "Students have certain professors. A student was presented to the faculty by their professor, and another was not.", sentence: "The student who her professor presented to the faculty influenced the dean.", label: "professor"},
#
# YDI: {story: "Manuscripts are written certain by professors. A manuscript was presented to the faculty by its professor, and another was not.", sentence: "The manuscript which its professor presented to the faculty influenced the dean.", label: "professor"},
#
# NQA: {story: "There is a certain professor. Some students were presented to the faculty by the professor, and others were not.", sentence: "Every student who the professor presented to the faculty influenced the dean.", label: "professor"},
#
# NQI: {story: "There is a certain professor. Some manuscripts were presented to the faculty by the professor, and others were not.", sentence: "Every manuscript which the professor presented to the faculty influenced the dean.", label: "professor"},
#
# NDA: {story: "There is a certain professor. A student was presented to the faculty by the professor, and another was not.", sentence: "The student who the professor presented to the faculty influenced the dean.", label: "professor"},
#
# NDI: {story: "There is a certain professor. A manuscript was presented to the faculty by the professor, and another was not.", sentence: "The manuscript which the professor presented to the faculty influenced the dean.", label: "professor"}
# }
# /Users/vinny/Downloads/scientist-expconfig.txt
# done! Yay!scientistxconfig =
# {itemtype: "test",
#
# YQA: {story: "Study participants are overseen by certain scientists. Some study participants were tested in the lab by their scientist, and others were not", sentence: "Every study participant who her scientist tested in the lab showed interesting results", label: "scientist"},
#
# YQI: {story: "Soil samples are overseen by certain scientists. Some soil sample were tested in the lab by their scientist, and others were not", sentence: "Every soil sample which its scientist tested in the lab showed interesting results", label: "scientist"},
#
# YDA: {story: "Study participants are overseen by certain scientists. A study participant was tested in the lab by her scientist, and another was not", sentence: "The study participant who her scientist tested in the lab showed interesting results", label: "scientist"},
#
# YDI: {story: "Soil samples are overseen by certain scientists. A soil sample was tested in the lab by its scientist, and another was not", sentence: "The soil sample which its scientist tested in the lab showed interesting results", label: "scientist"},
#
# NQA: {story: "There is a certain scientist. Some study participant were tested in the lab by that scientist, and others were not", sentence: "Every study participant who the scientist tested in the lab showed interesting results", label: "scientist"},
#
# NQI: {story: "There is a certain scientist. Some soil sample were tested in the lab by that scientist, and others were not", sentence: "Every soil sample which the scientist tested in the lab showed interesting results", label: "scientist"},
#
# NDA: {story: "There is a certain scientist. A study participant was tested in the lab by that scientist, and another was not", sentence: "The study participant who the scientist tested in the lab showed interesting results", label: "scientist"},
#
# NDI: {story: "There is a certain scientist. A soil sample was tested in the lab by that scientist, and another was not", sentence: "The soil sample which the scientist tested in the lab showed interesting results", label: "scientist"}
# }
# /Users/vinny/Downloads/chef-expconfig.txt
# done! Yay!chefxconfig =
# {itemtype: "test",
#
# YQA: {story: "Lunch ladies are paired with chefs. Some lunch ladies were recommended by their chef, and others were not", sentence: "Every lunch lady who her chef recommended eagerly delighted the students", label: "chef"},
#
# YQI: {story: "School lunches are given to chefs. Some school lunches were recommended by their chef, and others were not", sentence: "Every school lunch which its chef recommended eagerly delighted the students", label: "chef"},
#
# YDA: {story: "Lunch ladies are paired with chefs. A lunch lady was recommended by her chef, and another was not", sentence: "The lunch lady who her chef recommended eagerly delighted the students", label: "chef"},
#
# YDI: {story: "School lunches are given to chefs. A school lunch was recommended by its chef, and another was not", sentence: "The school lunch which its chef recommended eagerly delighted the students", label: "chef"},
#
# NQA: {story: "There is a certain chef. Some lunch ladies were recommended by that chef, and others were not", sentence: "Every lunch lady who the chef recommended eagerly delighted the students", label: "chef"},
#
# NQI: {story: "There is a certain chef. Some school lunches were recommended by that chef, and others were not", sentence: "Every school lunch which the chef recommended eagerly delighted the students", label: "chef"},
#
# NDA: {story: "There is a certain chef. A lunch lady was recommended by that chef, and another was not", sentence: "The lunch lady who the chef recommended eagerly delighted the students", label: "chef"},
#
# NDI: {story: "There is a certain chef. A school lunch was recommended by that chef, and another was not", sentence: "The school lunch which the chef recommended eagerly delighted the students", label: "chef"}
# }
# /Users/vinny/Downloads/priest-expconfig.txt
# done! Yay!priestxconfig =
# {itemtype: "test",
#
# YQA: {story: "Nuns are paired with certain priests. Some nuns were promoted by their priest and others were not", sentence: "Every nun who her priest promoted was an inspiration to many people", label: "priest"},
#
# YQI: {story: "Semons are delivered by certain priests. Some sermons were promoted by their priest, and others were not", sentence: "Every sermon which its priest promoted was an inspiration to many people", label: "priest"},
#
# YDA: {story: "Nuns are paired with certain priests. A nun was promoted by her priest, and another was not", sentence: "The nun who her priest promoted was an inspiration to many people", label: "priest"},
#
# YDI: {story: "Semons are delivered by certain priests. A sermon was promoted by its priest, and another was not", sentence: "The sermon which its priest promoted was an inspiration to many people", label: "priest"},
#
# NQA: {story: "There is a certain priest. Some nuns were promoted by that priest and others were not", sentence: "Every nun who the priest promoted was an inspiration to many people", label: "priest"},
#
# NQI: {story: "There is a certain priest. Some sermons were promoted by that priest, and others were not", sentence: "Every sermon which the priest promoted was an inspiration to many people", label: "priest"},
#
# NDA: {story: "There is a certain priest. A nun was promoted by that priest, and another was not", sentence: "The nun who the priest promoted was an inspiration to many people", label: "priest"},
#
# NDI: {story: "There is a certain priest. A sermon was promoted by that priest, and another was not", sentence: "The sermon which the priest promoted was an inspiration to many people", label: "priest"}
# }
# /Users/vinny/Downloads/bartender-expconfig.txt
# done! Yay!bartenderxconfig =
# {itemtype: "test",
#
# YQA: {story: "Waitresses are paired with certain bartenders. Some waitresses were praised by their bartender on Friday, and others were not", sentence: "Every waitress who her bartender praised on Friday impressed the diners", label: "bartender"},
#
# YQI: {story: "Cocktails are made by certain bartenders. Some cocktails were praised by their bartender on Friday, and others were not", sentence: "Every cocktail which its bartender praised on Friday impressed the diners", label: "bartender"},
#
# YDA: {story: "Waitresses are paired with certain bartenders. A waitress was praised by her bartender on Friday, and another was not", sentence: "The waitress who her bartender praised on Friday impressed the diners", label: "bartender"},
#
# YDI: {story: "Cocktails are made by certain bartenders. A cocktail was praised by its bartender on Friday, and another was not", sentence: "The cocktail which its bartender praised on Friday impressed the diners", label: "bartender"},
#
# NQA: {story: "There is a certain bartender. Some waitresses were praised by that bartender on Friday, and others were not", sentence: "Every waitress who the bartender praised on Friday impressed the diners", label: "bartender"},
#
# NQI: {story: "There is a certain bartender. Some cocktails were praised by that bartender on Friday, and others were not", sentence: "Every cocktail which the bartender praised on Friday impressed the diners", label: "bartender"},
#
# NDA: {story: "There is a certain bartender. A waitress was praised by that bartender on Friday, and another was not", sentence: "The waitress who the bartender praised on Friday impressed the diners", label: "bartender"},
#
# NDI: {story: "There is a certain bartender. A cocktail was praised by that bartender on Friday, and another was not", sentence: "The cocktail which the bartender praised on Friday impressed the diners", label: "bartender"}
# }
# /Users/vinny/Downloads/patient-expconfig.txt
# done! Yay!patientxconfig =
# {itemtype: "test",
#
# YQA: {story: "Midwives assist certain patients. Some midwives were requested by their patient, and others were not", sentence: "Every midwife who her patient requested was helpful in alleviating some pain", label: "patient"},
#
# YQI: {story: "Treatment is given to certain patients. Some treatments were requested by their patient, and others were not", sentence: "Every treatment which its patient requested was helpful in alleviating some pain", label: "patient"},
#
# YDA: {story: "Midwives assist certain patients. A midwife was requested by her patient, and another was not", sentence: "The midwife who her patient requested was helpful in alleviating some pain", label: "patient"},
#
# YDI: {story: "Treatment is given to certain patients. A treatment was requested by its patient, and another was not", sentence: "The treatment which its patient requested was helpful in alleviating some pain", label: "patient"},
#
# NQA: {story: "There is a certain patient. Some midwives were requested by that patient, and others were not", sentence: "Every midwife who the patient requested was helpful in alleviating some pain", label: "patient"},
#
# NQI: {story: "There is a certain patient. Some treatments were requested by that patient, and others were not", sentence: "Every treatment which the patient requested was helpful in alleviating some pain", label: "patient"},
#
# NDA: {story: "There is a certain patient. A midwife was requested by that patient, and another was not", sentence: "The midwife who the patient requested was helpful in alleviating some pain", label: "patient"},
#
# NDI: {story: "There is a certain patient. A treatment was requested by that patient, and another was not", sentence: "The treatment which the patient requested was helpful in alleviating some pain", label: "patient"}
# }
# /Users/vinny/Downloads/groom-expconfig.txt
# done! Yay!groomxconfig =
# {itemtype: "test",
#
# YQA: {story: "Brides will be married to certain grooms. Some brides were brought to the altar by their groom, and others were not", sentence: "Every bride who her groom brought to the altar wowed the audience", label: "groom"},
#
# YQI: {story: "Vows are given by certain grooms. Some vows were brought to the altar by their groom, and others were not", sentence: "Every vow which its groom brought to the altar wowed the audience", label: "groom"},
#
# YDA: {story: "Brides will be married to certain grooms. A bride was brought to the altar by her groom, and another was not", sentence: "The bride who her groom brought to the altar wowed the audience", label: "groom"},
#
# YDI: {story: "Vows are given by certain grooms. A vow was brought to the altar by its groom, and another was not", sentence: "The vow which its groom brought to the altar wowed the audience", label: "groom"},
#
# NQA: {story: "There is a certain groom. Some brides were brought to the altar by that groom, and others were not", sentence: "Every bride who the groom brought to the altar wowed the audience", label: "groom"},
#
# NQI: {story: "There is a certain groom. Some vows were brought to the altar by that groom, and others were not", sentence: "Every vow which the groom brought to the altar wowed the audience", label: "groom"},
#
# NDA: {story: "There is a certain groom. A bride was brought to the altar by that groom, and another was not", sentence: "The bride who the groom brought to the altar wowed the audience", label: "groom"},
#
# NDI: {story: "There is a certain groom. A vow was brought to the altar by that groom, and another was not", sentence: "The vow which the groom brought to the altar wowed the audience", label: "groom"}
# }
# /Users/vinny/Downloads/troop leader-expconfig.txt
# done! Yay!troop leaderxconfig =
# {itemtype: "test",
#
# YQA: {story: "Girls scouts are paired with certain troop leaders. Some girl scouts were introduced to the parents by their troop leader, and others were not", sentence: "Every girl scout who her troop leader introduced to the parents became widely popular", label: "troop leader"},
#
# YQI: {story: "Camping trips are paired with certain troop leaders. Some camping trips were introduced to the parents by their troop leader, and others were not", sentence: "Every camping trip which its troop leader introduced to the parents became widely popular", label: "troop leader"},
#
# YDA: {story: "Girls scouts are paired with certain troop leaders. A girl scout was introduced to the parents by her troop leader, and another was not", sentence: "The girl scout who her troop leader introduced to the parents became widely popular", label: "troop leader"},
#
# YDI: {story: "Camping trips are paired with certain troop leaders. A camping trip was introduced to the parents by its troop leader, and another was not", sentence: "The camping trip which its troop leader introduced to the parents became widely popular", label: "troop leader"},
#
# NQA: {story: "There is a certain troop leader. Some girl scouts were introduced to the parents by that troop leader, and others were not", sentence: "Every girl scout who the troop leader introduced to the parents became widely popular", label: "troop leader"},
#
# NQI: {story: "There is a certain troop leader. Some camping trips were introduced to the parents by that troop leader, and others were not", sentence: "Every camping trip which the troop leader introduced to the parents became widely popular", label: "troop leader"},
#
# NDA: {story: "There is a certain troop leader. A girl scout was introduced to the parents by that troop leader, and another was not", sentence: "The girl scout who the troop leader introduced to the parents became widely popular", label: "troop leader"},
#
# NDI: {story: "There is a certain troop leader. A camping trip was introduced to the parents by that troop leader, and another was not", sentence: "The camping trip which the troop leader introduced to the parents became widely popular", label: "troop leader"}
# }
# /Users/vinny/Downloads/CEO-expconfig.txt
# done! Yay!CEOxconfig =
# {itemtype: "test",
#
# YQA: {story: "Secretaries are paired with certain CEOs. Some secretaries were remembered by their CEO, and others were not", sentence: "Every secretary who her CEO remembered well impressed the board of trustees", label: "CEO"},
#
# YQI: {story: "Contracts are paired with certain CEOs. Some contracts were remembered by their CEO, and others were not", sentence: "Every contract which its CEO remembered well impressed the board of trustees", label: "CEO"},
#
# YDA: {story: "Secretaries are paired with certain CEOs. A secretary was remembered by her CEO, and another was not", sentence: "The secretary who her CEO remembered well impressed the board of trustees", label: "CEO"},
#
# YDI: {story: "Contracts are paired with certain CEOs. A contract was remembered by its CEO, and another was not", sentence: "The contract which its CEO remembered well impressed the board of trustees", label: "CEO"},
#
# NQA: {story: "There is a certain CEO. Some secretaries were remembered by that CEO, and others were not", sentence: "Every secretary who the CEO remembered well impressed the board of trustees", label: "CEO"},
#
# NQI: {story: "There is a certain CEO. Some contracts were remembered by that CEO, and others were not", sentence: "Every contract which the CEO remembered well impressed the board of trustees", label: "CEO"},
#
# NDA: {story: "There is a certain CEO. A secretary was remembered by that CEO, and another was not", sentence: "The secretary who the CEO remembered well impressed the board of trustees", label: "CEO"},
#
# NDI: {story: "There is a certain CEO. A contract was remembered by that CEO, and another was not", sentence: "The contract which the CEO remembered well impressed the board of trustees", label: "CEO"}
# }
# /Users/vinny/Downloads/dentist-expconfig.txt
# done! Yay!dentistxconfig =
# {itemtype: "test",
#
# YQA: {story: "Assistants serve certain dentists. Some assistants were selected by their dentist, and others were not", sentence: "Every assistant who her dentist selected to help with the procedure stressed out the patient", label: "dentist"},
#
# YQI: {story: "Tools are used by certain dentists. Some tools were selected by their dentist, and others were not", sentence: "Every tool which its dentist selected to help with the procedure stressed out the patient", label: "dentist"},
#
# YDA: {story: "Assistants serve certain dentists. An assistant was selected by her dentist, and another was not", sentence: "The assistant who her dentist selected to help with the procedure stressed out the patient", label: "dentist"},
#
# YDI: {story: "Tools are used by certain dentists. A tool was selected by its dentist, and another was not", sentence: "The tool which its dentist selected to help with the procedure stressed out the patient", label: "dentist"},
#
# NQA: {story: "There is a certain dentist. Some assistants were selected by that dentist, and others were not", sentence: "Every assistant who the dentist selected to help with the procedure stressed out the patient", label: "dentist"},
#
# NQI: {story: "There is a certain dentist. Some tools were selected by that dentist, and others were not", sentence: "Every tool which the dentist selected to help with the procedure stressed out the patient", label: "dentist"},
#
# NDA: {story: "There is a certain dentist. An assistant was selected by that dentist, and another was not", sentence: "The assistant who the dentist selected to help with the procedure stressed out the patient", label: "dentist"},
#
# NDI: {story: "There is a certain dentist. A tool was selected by that dentist, and another was not", sentence: "The tool which the dentist selected to help with the procedure stressed out the patient", label: "dentist"}
# }
# /Users/vinny/Downloads/nutritionist-expconfig.txt
# done! Yay!nutritionistxconfig =
# {itemtype: "test",
#
# YQA: {story: "Influencers have certain nutritionists. Some influencers were denounced in a blogpost by their nutritionist, and others were not", sentence: "Every influencer who her nutritionist denounced in a blogpost gained a cult-like following", label: "nutritionist"},
#
# YQI: {story: "Mealkits are noticed by certain nutritionists. Some mealkits were denounced in a blogpost by their nutritionist, and others were not", sentence: "Every mealkit which its nutritionist denounced in a blogpost gained a cult-like following", label: "nutritionist"},
#
# YDA: {story: "Influencers have certain nutritionists. A influencer was denounced in a blogpost by her nutritionist, and another was not", sentence: "The influencer who her nutritionist denounced in a blogpost gained a cult-like following", label: "nutritionist"},
#
# YDI: {story: "Mealkits are noticed by certain nutritionists. A mealkit was denounced in a blogpost by its nutritionist, and another was not", sentence: "The mealkit which its nutritionist denounced in a blogpost gained a cult-like following", label: "nutritionist"},
#
# NQA: {story: "There is a certain nutritionist. Some influencers were denounced in a blogpost by that nutritionist, and others were not", sentence: "Every influencer who the nutritionist denounced in a blogpost gained a cult-like following", label: "nutritionist"},
#
# NQI: {story: "There is a certain nutritionist. Some mealkits were denounced in a blogpost by that nutritionist, and others were not", sentence: "Every mealkit which the nutritionist denounced in a blogpost gained a cult-like following", label: "nutritionist"},
#
# NDA: {story: "There is a certain nutritionist. A influencer was denounced in a blogpost by that nutritionist, and another was not", sentence: "The influencer who the nutritionist denounced in a blogpost gained a cult-like following", label: "nutritionist"},
#
# NDI: {story: "There is a certain nutritionist. A mealkit was denounced in a blogpost by that nutritionist, and another was not", sentence: "The mealkit which the nutritionist denounced in a blogpost gained a cult-like following", label: "nutritionist"}
# }
# /Users/vinny/Downloads/choreographer-expconfig.txt
# done! Yay!choreographerxconfig =
# {itemtype: "test",
#
# YQA: {story: "Ballerinas are instructed by certain choreographer. Some ballerinas were discussed at the party by their choreographer, and others were not", sentence: "Every ballerina who her choreographer discussed at the party never had a debut", label: "choreographer"},
#
# YQI: {story: "Ballets are studied by certain choreographers. Some ballets were discussed at the party by their choreographer, and others were not", sentence: "Every ballet which its choreographer discussed at the party never had a debut", label: "choreographer"},
#
# YDA: {story: "Ballerinas are instructed by certain choreographer. A ballerina was discussed at the party by her choreographer, and another was not", sentence: "The ballerina who her choreographer discussed at the party never had a debut", label: "choreographer"},
#
# YDI: {story: "Ballets are studied by certain choreographers. A ballet was discussed at the party by its choreographer, and another was not", sentence: "The ballet which its choreographer discussed at the party never had a debut", label: "choreographer"},
#
# NQA: {story: "There is a certain choreographer. Some ballerinas were discussed at the party by that choreographer, and others were not", sentence: "Every ballerina who the choreographer discussed at the party never had a debut", label: "choreographer"},
#
# NQI: {story: "There is a certain choreographer. Some ballets were discussed at the party by that choreographer, and others were not", sentence: "Every ballet which the choreographer discussed at the party never had a debut", label: "choreographer"},
#
# NDA: {story: "There is a certain choreographer. A ballerina was discussed at the party by that choreographer, and another was not", sentence: "The ballerina who the choreographer discussed at the party never had a debut", label: "choreographer"},
#
# NDI: {story: "There is a certain choreographer. A ballet was discussed at the party by that choreographer, and another was not", sentence: "The ballet which the choreographer discussed at the party never had a debut", label: "choreographer"}
# }
# /Users/vinny/Downloads/stylist-expconfig.txt
# done! Yay!stylistxconfig =
# {itemtype: "test",
#
# YQA: {story: "Hair dressers are associated with certain stylists. Some hair dressers were complimented enthusiastically by their stylist, and others were not", sentence: "Every hair dresser who her stylist complimented enthusiastically provided top of the line coloring services", label: "stylist"},
#
# YQI: {story: "Hair salons are owned by certain stylists. Some hair salons were complimented enthusiastically by their stylist, and others were not", sentence: "Every hair salon which its stylist complimented enthusiastically provided top of the line coloring services", label: "stylist"},
#
# YDA: {story: "Hair dressers are associated with certain stylists. A hair dresser was complimented enthusiastically by her stylist, and another was not", sentence: "The hair dresser who her stylist complimented enthusiastically provided top of the line coloring services", label: "stylist"},
#
# YDI: {story: "Hair salons are owned by certain stylists. A hair salon was complimented enthusiastically by its stylist, and another was not", sentence: "The hair salon which its stylist complimented enthusiastically provided top of the line coloring services", label: "stylist"},
#
# NQA: {story: "There is a certain stylist. Some hair dressers were complimented enthusiastically by that stylist, and others were not", sentence: "Every hair dresser who the stylist complimented enthusiastically provided top of the line coloring services", label: "stylist"},
#
# NQI: {story: "There is a certain stylist. Some hair salons were complimented enthusiastically by that stylist, and others were not", sentence: "Every hair salon which the stylist complimented enthusiastically provided top of the line coloring services", label: "stylist"},
#
# NDA: {story: "There is a certain stylist. A hair dresser was complimented enthusiastically by that stylist, and another was not", sentence: "The hair dresser who the stylist complimented enthusiastically provided top of the line coloring services", label: "stylist"},
#
# NDI: {story: "There is a certain stylist. A hair salon was complimented enthusiastically by that stylist, and another was not", sentence: "The hair salon which the stylist complimented enthusiastically provided top of the line coloring services", label: "stylist"}
# }
# /Users/vinny/Downloads/fan-expconfig.txt
# done! Yay!fanxconfig =
# {itemtype: "test",
#
# YQA: {story: "Actresses have certain #1 fans. Some actresses were lauded on Twitter by their fan, and others were not", sentence: "Every actress who her #1 fan lauded on twitter was nominated for an award", label: "fan"},
#
# YQI: {story: "Performances have certain #1 fans. Some performances were lauded on Twitter by their fan, and others were not", sentence: "Every performance which its #1 fan lauded on twitter was nominated for an award", label: "fan"},
#
# YDA: {story: "Actresses have certain #1 fans. A actress was lauded on Twitter by her fan, and another was not", sentence: "The actress who her #1 fan lauded on twitter was nominated for an award", label: "fan"},
#
# YDI: {story: "Performances have certain #1 fans. A performance was lauded on Twitter by its fan, and another was not", sentence: "The performance which its #1 fan lauded on twitter was nominated for an award", label: "fan"},
#
# NQA: {story: "There is a certain #1 fan. Some actresses were lauded on Twitter by that fan, and others were not", sentence: "Every actress who the #1 fan lauded on twitter was nominated for an award", label: "fan"},
#
# NQI: {story: "There is a certain #1 fan. Some performances were lauded on Twitter by that fan, and others were not", sentence: "Every performance which the #1 fan lauded on twitter was nominated for an award", label: "fan"},
#
# NDA: {story: "There is a certain #1 fan. A actress was lauded on Twitter by that fan, and another was not", sentence: "The actress who the #1 fan lauded on twitter was nominated for an award", label: "fan"},
#
# NDI: {story: "There is a certain #1 fan. A performance was lauded on Twitter by that fan, and another was not", sentence: "The performance which the #1 fan lauded on twitter was nominated for an award", label: "fan"}
# }
# /Users/vinny/Downloads/coach-expconfig.txt
# done! Yay!coachxconfig =
# {itemtype: "test",
#
# YQA: {story: "Gymnasts are instructed by certain coaches. Some gymnasts were criticized by their coach, and others were not", sentence: "Every gymnast who her coach criticized failed to qualify for nationals", label: "coach"},
#
# YQI: {story: "Routines are overseen by certain coaches. Some routines were criticized by their coach, and others were not", sentence: "Every routine which its coach criticized failed to qualify for nationals", label: "coach"},
#
# YDA: {story: "Gymnasts are instructed by certain coaches. A gymnast was criticized by her coach, and another was not", sentence: "The gymnast who her coach criticized failed to qualify for nationals", label: "coach"},
#
# YDI: {story: "Routines are overseen by certain coaches. A routine was criticized by its coach, and another was not", sentence: "The routine which its coach criticized failed to qualify for nationals", label: "coach"},
#
# NQA: {story: "There is a certain coach. Some gymnasts were criticized by that coach, and others were not", sentence: "Every gymnast who the coach criticized failed to qualify for nationals", label: "coach"},
#
# NQI: {story: "There is a certain coach. Some routines were criticized by that coach, and others were not", sentence: "Every routine which the coach criticized failed to qualify for nationals", label: "coach"},
#
# NDA: {story: "There is a certain coach. A gymnast was criticized by that coach, and another was not", sentence: "The gymnast who the coach criticized failed to qualify for nationals", label: "coach"},
#
# NDI: {story: "There is a certain coach. A routine was criticized by that coach, and another was not", sentence: "The routine which the coach criticized failed to qualify for nationals", label: "coach"}
# }
# /Users/vinny/Downloads/queen-expconfig.txt
# done! Yay!queenxconfig =
# {itemtype: "test",
#
# YQA: {story: "Princesses are paired with certain queens. Some princesses are admired by their queens, and others are not.", sentence: "Every princess who her queen admired was featured in the royal portrait", label: "queen"},
#
# YQI: {story: "Princesses are paired with certain queens. Some tiaras are admired by their queens, and others are not.", sentence: "Every tiara which its queen admired was featured in the royal portrait", label: "queen"},
#
# YDA: {story: "Princesses are paired with certain queens. A princess was admired by her queen and another was not.", sentence: "The princess who her queen admired was featured in the royal portrait", label: "queen"},
#
# YDI: {story: "Princesses are paired with certain queens. A tiara was admired by its queen, and another was not.", sentence: "The tiara which its queen admired was featured in the royal portrait", label: "queen"},
#
# NQA: {story: "There is a certain queen. Some princesses are admired by that queen, and others are not.", sentence: "Every princess who the queen admired was featured in the royal portrait", label: "queen"},
#
# NQI: {story: "There is a certain queen. Some tiaras are admired by that queens, and others are not.", sentence: "Every tiara which the queen admired was featured in the royal portrait", label: "queen"},
#
# NDA: {story: "There is a certain queen. A princess was admired by that queen and another was not.", sentence: "The princess who the queen admired was featured in the royal portrait", label: "queen"},
#
# NDI: {story: "There is a certain queen. A tiara was admired by that queen, and another was not.", sentence: "The tiara which the queen admired was in the royal portrait", label: "queen"}
# }
